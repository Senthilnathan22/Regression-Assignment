# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset, drop_first=True, dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(independent, dependent, test_size=1/3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostRegressor
param_grid={'loss':['linear', 'square', 'exponential'], 'learning_rate':[1.0,10.0,100.0], 'n_estimators':[10,50,100]}
grid=GridSearchCV(AdaBoostRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# C:\Users\Bagirathan\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [1.0, 10.0, 100.0],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_score value for best parameter:{}".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter:{'learning_rate': 1.0, 'loss': 'linear', 'n_estimators': 10} 0.876023570890767

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.046175      0.004686         0.006658        0.002983
# 1        0.044191      0.009011         0.007258        0.001696
# 2        0.042002      0.004941         0.006999        0.002138
# 3        0.045346      0.005233         0.002828        0.003748
# 4        0.181923      0.003623         0.013802        0.004409
# 5        0.349392      0.003183         0.028414        0.004145
# 6        0.042180      0.003267         0.007464        0.003240
# 7        0.191194      0.017751         0.015530        0.004042
# 8        0.370056      0.005838         0.029458        0.004271
# 9        0.038575      0.003995         0.005740        0.001479
# 10       0.159719      0.003925         0.013087        0.003134
# 11       0.318399      0.008438         0.025803        0.003413
# 12       0.034135      0.003968         0.006744        0.002739
# 13       0.159173      0.001892         0.014726        0.002091
# 14       0.316281      0.007480         0.026997        0.003807
# 15       0.037918      0.005838         0.003653        0.002595
# 16       0.161833      0.006012         0.015108        0.004347
# 17       0.330590      0.011463         0.025491        0.004935
# 18       0.035825      0.004498         0.005197        0.004466
# 19       0.153413      0.001758         0.016697        0.002165
# 20       0.307226      0.007990         0.028300        0.003922
# 21       0.036072      0.004225         0.004627        0.003986
# 22       0.159699      0.003558         0.014650        0.004001
# 23       0.306556      0.000805         0.022852        0.006816
# 24       0.016212      0.004093         0.005737        0.003971
# 25       0.026705      0.010771         0.004830        0.003268
# 26       0.025552      0.015174         0.004355        0.003913
#
#     param_learning_rate   param_loss  param_n_estimators  \
# 0                   1.0       linear                  10
# 1                   1.0       linear                  50
# 2                   1.0       linear                 100
# 3                   1.0       square                  10
# 4                   1.0       square                  50
# 5                   1.0       square                 100
# 6                   1.0  exponential                  10
# 7                   1.0  exponential                  50
# 8                   1.0  exponential                 100
# 9                  10.0       linear                  10
# 10                 10.0       linear                  50
# 11                 10.0       linear                 100
# 12                 10.0       square                  10
# 13                 10.0       square                  50
# 14                 10.0       square                 100
# 15                 10.0  exponential                  10
# 16                 10.0  exponential                  50
# 17                 10.0  exponential                 100
# 18                100.0       linear                  10
# 19                100.0       linear                  50
# 20                100.0       linear                 100
# 21                100.0       square                  10
# 22                100.0       square                  50
# 23                100.0       square                 100
# 24                100.0  exponential                  10
# 25                100.0  exponential                  50
# 26                100.0  exponential                 100
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.773493
# 1   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.771498
# 2   {'learning_rate': 1.0, 'loss': 'linear', 'n_es...           0.767758
# 3   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.552246
# 4   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.316896
# 5   {'learning_rate': 1.0, 'loss': 'square', 'n_es...           0.332639
# 6   {'learning_rate': 1.0, 'loss': 'exponential', ...           0.760241
# 7   {'learning_rate': 1.0, 'loss': 'exponential', ...           0.454240
# 8   {'learning_rate': 1.0, 'loss': 'exponential', ...           0.365309
# 9   {'learning_rate': 10.0, 'loss': 'linear', 'n_e...         -21.417457
# 10  {'learning_rate': 10.0, 'loss': 'linear', 'n_e...         -21.051244
# 11  {'learning_rate': 10.0, 'loss': 'linear', 'n_e...         -21.012391
# 12  {'learning_rate': 10.0, 'loss': 'square', 'n_e...         -23.223009
# 13  {'learning_rate': 10.0, 'loss': 'square', 'n_e...         -23.210534
# 14  {'learning_rate': 10.0, 'loss': 'square', 'n_e...         -23.379554
# 15  {'learning_rate': 10.0, 'loss': 'exponential',...          -1.097381
# 16  {'learning_rate': 10.0, 'loss': 'exponential',...          -0.762343
# 17  {'learning_rate': 10.0, 'loss': 'exponential',...          -0.680872
# 18  {'learning_rate': 100.0, 'loss': 'linear', 'n_...         -24.292199
# 19  {'learning_rate': 100.0, 'loss': 'linear', 'n_...         -24.292199
# 20  {'learning_rate': 100.0, 'loss': 'linear', 'n_...         -24.292199
# 21  {'learning_rate': 100.0, 'loss': 'square', 'n_...          -3.615164
# 22  {'learning_rate': 100.0, 'loss': 'square', 'n_...         -24.292199
# 23  {'learning_rate': 100.0, 'loss': 'square', 'n_...         -24.292199
# 24  {'learning_rate': 100.0, 'loss': 'exponential'...         -24.292199
# 25  {'learning_rate': 100.0, 'loss': 'exponential'...         -23.293019
# 26  {'learning_rate': 100.0, 'loss': 'exponential'...         -24.292199
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.780216           0.829318           0.833312
# 1            0.772603           0.790770           0.831951
# 2            0.747433           0.839826           0.818531
# 3            0.570025           0.699676           0.631831
# 4            0.364162           0.568908           0.366665
# 5            0.346567           0.524881           0.341592
# 6            0.706409           0.802702           0.777569
# 7            0.458930           0.620070           0.517050
# 8            0.374880           0.567576           0.435279
# 9          -18.505498         -12.002795         -17.641078
# 10         -19.479881         -13.996926         -17.792133
# 11         -19.441478         -13.886246         -18.013784
# 12         -21.844043         -14.327486         -16.499296
# 13         -21.816231         -14.339459         -19.594957
# 14         -21.944671         -14.339459         -19.594957
# 15          -1.554011          -0.288768          -0.146592
# 16          -0.642298           0.027694          -0.644969
# 17          -0.936755          -0.119814          -0.493992
# 18         -22.822468         -15.034235         -20.507593
# 19         -22.822468         -15.034235         -20.507593
# 20         -22.822468         -15.034235         -20.507593
# 21          -2.052465          -1.952835         -20.507593
# 22         -22.822468         -15.034235         -20.507593
# 23         -22.822468         -15.034235         -20.507593
# 24         -21.805149         -14.392635         -16.499296
# 25         -21.805149         -14.353152         -19.623574
# 26         -21.805149         -14.327486         -20.507593
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.785179         0.800304        0.025622                1
# 1            0.793772         0.792119        0.021896                2
# 2            0.777569         0.790223        0.033934                3
# 3            0.710228         0.632801        0.064650                5
# 4            0.591336         0.441593        0.114709                8
# 5            0.563077         0.421751        0.100626                9
# 6            0.764340         0.762252        0.031615                4
# 7            0.655214         0.541101        0.082624                6
# 8            0.607556         0.470120        0.099656                7
# 9          -11.402251       -16.193816        3.879398               14
# 10         -11.271898       -16.718416        3.595081               15
# 11         -11.388053       -16.748391        3.576611               16
# 12         -11.116014       -17.401970        4.547461               17
# 13         -11.296412       -18.051519        4.529493               20
# 14         -11.281505       -18.108029        4.593981               21
# 15           0.278222        -0.561706        0.666920               12
# 16          -0.705131        -0.545410        0.289937               11
# 17          -0.440299        -0.534346        0.270449               10
# 18         -11.860208       -18.903340        4.723318               23
# 19         -11.860208       -18.903340        4.723318               23
# 20         -11.860208       -18.903340        4.723318               23
# 21          -1.666547        -5.958921        7.306034               13
# 22         -11.860208       -18.903340        4.723318               23
# 23         -11.860208       -18.903340        4.723318               23
# 24         -11.203619       -17.638579        4.793199               18
# 25         -11.116014       -18.038182        4.600275               19
# 26         -11.504788       -18.487443        4.792621               22

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 54
# BMI: 35
# Children: 4
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[47480.75086212]
